# %% [markdown]
# # Tools for Car Object Detection - R-CNN Model
#
# <img width="1109" alt="Screen Shot 2023-10-03 at 12 13 27 PM" src="https://github.com/nickthetj/CarObjectDetection/assets/37059423/bf1b8802-b453-44ea-8dde-fe1a0ddcfe1d">
# (Source: Zapp2Photo/Shutterstock.com)
#
# ## Overview
# Object recognition is the linchpin for self-driving cars. It enables self-driving cars to identify and respond to objects like pedestrians and vehicles in real-time, ensuring safer autonomous driving. This notebook will walk through one of three object detection models that can identify and draw bounding-boxes around cars on the road: YOLOv8, R-CNN, and Bounding Box Regression (BB). The YOLOv8 model was implemented with the pre-packaged model from Ultralytics, and R-CNN and BB were built from the ground up. We will walk through differences between each model on a conceptual level, their implementation and respective evaluation scores.
#
# ## Business Problem
# These object detection models were developed as a tool for autonomous vehicles and traffic safety cameras to enable the cameras to perceive and understand its environment by identifying and locating objects of interest in real-time. Specifically in identifying and locating where cars are in a picture.

# %% [markdown]
# <img width="1109" alt="Screen Shot 2023-10-03 at 12 13 27 PM" src="https://github.com/nickthetj/CarObjectDetection/assets/37059423/bf1b8802-b453-44ea-8dde-fe1a0ddcfe1d">
# (Source: Zapp2Photo/Shutterstock.com)

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications import MobileNetV2
from tensorflow.keras.layers import AveragePooling2D, Dropout, Flatten, Dense, Input
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.applications.mobilenet_v2 import preprocess_input
from tensorflow.keras.preprocessing.image import img_to_array, load_img
from tensorflow.keras.utils import to_categorical
from sklearn.preprocessing import LabelBinarizer
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report
from imutils import paths
import pandas as pd
import matplotlib.pyplot as plt
import cv2
import numpy as np
import argparse
import pickle
import os

# %%
path = "data/training_images/"
annot = "data/annotations"

# %%
def compute_iou(boxA, boxB):
	# determine the (x, y)-coordinates of the intersection rectangle
	xA = max(boxA[0], boxB[0])
	yA = max(boxA[1], boxB[1])
	xB = min(boxA[2], boxB[2])
	yB = min(boxA[3], boxB[3])
	# compute the area of intersection rectangle
	interArea = max(0, xB - xA + 1) * max(0, yB - yA + 1)
	# compute the area of both the prediction and ground-truth
	# rectangles
	boxAArea = (boxA[2] - boxA[0] + 1) * (boxA[3] - boxA[1] + 1)
	boxBArea = (boxB[2] - boxB[0] + 1) * (boxB[3] - boxB[1] + 1)
	# compute the intersection over union by taking the intersection
	# area and dividing it by the sum of prediction + ground-truth
	# areas - the intersection area
	iou = interArea / float(boxAArea + boxBArea - interArea)
	# return the intersection over union value
	return iou

# %%
# loop over the output positive and negative directories
for dirPath in (path+'car', path+'nocar'):
	# if the output directory does not exist yet, create it
	if not os.path.exists(dirPath):
		os.makedirs(dirPath)
		
# grab all image paths in the input images directory
imagePaths = list(paths.list_images(path+'training_images'))

# initialize the total number of positive and negative images we have
# saved to disk so far
totalPositive = 0
totalNegative = 0

# %%
# loop over the image paths
for (e, i) in enumerate(os.listdir(annot)):
	# show a progress report
	print(f"[INFO] processing image {i}")
	
	imageName = i.split(".")[0]+".jpg"
	img = cv2.imread(os.path.join(path,imageName))
	df = pd.read_csv(os.path.join(annot,i))
	# extract image dimensions
	(h,w) = img.shape[:2]
	gtBoxes = []
	for row in df.iterrows():
		# extract bounding box coordinates
		x1 = int(row[1][0].split(" ")[0])
		y1 = int(row[1][0].split(" ")[1])
		x2 = int(row[1][0].split(" ")[2])
		y2 = int(row[1][0].split(" ")[3])
	
		# truncate any bounding box coordinates that may fall
		# outside the boundaries of the image
		x1 = max(0, x1)
		y1 = max(0, y1)
		x2 = min(w, x2)
		y2 = min(h, y2)
		
		gtBoxes.append((x1, y1, x2, y2))
	
	# run selective search on the image and initialize our list of
	# proposed boxes
	ss = cv2.ximgproc.segmentation.createSelectiveSearchSegmentation()
	ss.setBaseImage(img)
	ss.switchToSelectiveSearchFast()
	rects = ss.process()
	proposedRects= []
	# loop over the rectangles generated by selective search
	for (x, y, w, h) in rects:
		# convert our bounding boxes from (x, y, w, h) to (startX,
		# startY, startX, endY)
		proposedRects.append((x, y, x + w, y + h))

	# initialize counters used to count the number of positive and
	# negative ROIs saved thus far
	positiveROIs = 0
	negativeROIs = 0
	# loop over the maximum number of region proposals
	for proposedRect in proposedRects[:2000]:
		# unpack the proposed rectangle bounding box
		(propStartX, propStartY, propEndX, propEndY) = proposedRect
		# loop over the ground-truth bounding boxes
		for gtBox in gtBoxes:
			# compute the intersection over union between the two
			# boxes and unpack the ground-truth bounding box
			iou = compute_iou(gtBox, proposedRect)
			(gtStartX, gtStartY, gtEndX, gtEndY) = gtBox
			# initialize the ROI and output path
			roi = None
			outputPath = None
			# check to see if the IOU is greater than 70% *and* that
			# we have not hit our positive count limit
			if iou > 0.7 and positiveROIs <= 3:
				# extract the ROI and then derive the output path to
				# the positive instance
				roi = img[propStartY:propEndY, propStartX:propEndX]
				filename = "{}.png".format(totalPositive)
				outputPath = os.path.sep.join(['data/car/',
					filename])
				# increment the positive counters
				positiveROIs += 1
				totalPositive += 1
			# determine if the proposed bounding box falls *within*
			# the ground-truth bounding box
			fullOverlap = propStartX >= gtStartX
			fullOverlap = fullOverlap and propStartY >= gtStartY
			fullOverlap = fullOverlap and propEndX <= gtEndX
			fullOverlap = fullOverlap and propEndY <= gtEndY
				# check to see if there is not full overlap *and* the IoU
			# is less than 5% *and* we have not hit our negative
			# count limit
			if not fullOverlap and iou < 0.05 and negativeROIs <= 3:
				# extract the ROI and then derive the output path to
				# the negative instance
				roi = img[propStartY:propEndY, propStartX:propEndX]
				filename = "{}.png".format(totalNegative)
				outputPath = os.path.sep.join(['data/nocar/',
					filename])
				# increment the negative counters
				negativeROIs += 1
				totalNegative += 1
			# check to see if both the ROI and output path are valid
			if roi is not None and outputPath is not None:
				# resize the ROI to the input dimensions of the CNN
				# that we'll be fine-tuning, then write the ROI to
				# disk
				roi = cv2.resize(roi, (224, 224),
					interpolation=cv2.INTER_CUBIC)
				cv2.imwrite(outputPath, roi)
			# print(f'Positive ROIs: {positiveROIs}, Negative ROIs: {negativeROIs}')
# Out:
# [INFO] processing image vid_4_30000.csv
# [INFO] processing image vid_4_9660.csv
# [INFO] processing image vid_4_28840.csv
# [INFO] processing image vid_4_17440.csv
# [INFO] processing image vid_4_21680.csv
# [INFO] processing image vid_4_26460.csv
# [INFO] processing image vid_4_12060.csv
# [INFO] processing image vid_4_1980.csv
# [INFO] processing image vid_4_8740.csv
# [INFO] processing image vid_4_29960.csv
# [INFO] processing image vid_4_6180.csv
# [INFO] processing image vid_4_26500.csv
# [INFO] processing image vid_4_19900.csv
# [INFO] processing image vid_4_16400.csv
# [INFO] processing image vid_4_12100.csv
# [INFO] processing image vid_4_18820.csv
# [INFO] processing image vid_4_9700.csv
# [INFO] processing image vid_4_6340.csv
# [INFO] processing image vid_4_10500.csv
# [INFO] processing image vid_4_11420.csv
# [INFO] processing image vid_4_19040.csv
# [INFO] processing image vid_4_21520.csv
# [INFO] processing image vid_4_15040.csv
# [INFO] processing image vid_4_21440.csv
# [INFO] processing image vid_4_17680.csv
# [INFO] processing image vid_4_700.csv
# [INFO] processing image vid_4_6220.csv
# [INFO] processing image vid_4_14160.csv
# [INFO] processing image vid_4_8580.csv
# [INFO] processing image vid_4_13800.csv
# [INFO] processing image vid_4_28880.csv
# [INFO] processing image vid_4_21640.csv
# [INFO] processing image vid_4_1940.csv
# [INFO] processing image vid_4_2520.csv
# [INFO] processing image vid_4_14360.csv
# [INFO] processing image vid_4_18200.csv
# [INFO] processing image vid_4_1820.csv
# [INFO] processing image vid_4_18360.csv
# [INFO] processing image vid_4_3560.csv
# [INFO] processing image vid_4_4540.csv
# [INFO] processing image vid_4_12300.csv
# [INFO] processing image vid_4_6380.csv
# [INFO] processing image vid_4_9500.csv
# [INFO] processing image vid_4_22980.csv
# [INFO] processing image vid_4_19080.csv
# [INFO] processing image vid_4_17640.csv
# [INFO] processing image vid_4_1000.csv
# [INFO] processing image vid_4_21480.csv
# [INFO] processing image vid_4_9460.csv
# [INFO] processing image vid_4_12260.csv
# [INFO] processing image vid_4_920.csv
# [INFO] processing image vid_4_13620.csv
# [INFO] processing image vid_4_17320.csv
# [INFO] processing image vid_4_3820.csv
# [INFO] processing image vid_4_26300.csv
# [INFO] processing image vid_4_17240.csv
# [INFO] processing image vid_4_13740.csv
# [INFO] processing image vid_4_9060.csv
# [INFO] processing image vid_4_2120.csv
# [INFO] processing image vid_4_6420.csv
# [INFO] processing image vid_4_21240.csv
# [INFO] processing image vid_4_13580.csv
# [INFO] processing image vid_4_17080.csv
# [INFO] processing image vid_4_3160.csv
# [INFO] processing image vid_4_8960.csv
# [INFO] processing image vid_4_21320.csv
# [INFO] processing image vid_4_2040.csv
# [INFO] processing image vid_4_9840.csv
# [INFO] processing image vid_4_29540.csv
# [INFO] processing image vid_4_11020.csv
# [INFO] processing image vid_4_3360.csv
# [INFO] processing image vid_4_14400.csv
# [INFO] processing image vid_4_10100.csv
# [INFO] processing image vid_4_10060.csv
# [INFO] processing image vid_4_13780.csv
# [INFO] processing image vid_4_880.csv
# [INFO] processing image vid_4_3200.csv
# [INFO] processing image vid_4_16160.csv
# [INFO] processing image vid_4_8340.csv
# [INFO] processing image vid_4_22560.csv
# [INFO] processing image vid_4_9260.csv
# [INFO] processing image vid_4_17040.csv
# [INFO] processing image vid_4_21280.csv
# [INFO] processing image vid_4_11380.csv
# [INFO] processing image vid_4_9300.csv
# [INFO] processing image vid_4_1760.csv
# [INFO] processing image vid_4_17120.csv
# [INFO] processing image vid_4_16000.csv
# [INFO] processing image vid_4_9880.csv
# [INFO] processing image vid_4_8220.csv
# [INFO] processing image vid_4_2080.csv
# [INFO] processing image vid_4_11960.csv
# [INFO] processing image vid_4_21620.csv
# [INFO] processing image vid_4_3460.csv
# [INFO] processing image vid_4_1920.csv
# [INFO] processing image vid_4_2540.csv
# [INFO] processing image vid_4_1840.csv
# [INFO] processing image vid_4_28200.csv
# [INFO] processing image vid_4_8680.csv
# [INFO] processing image vid_4_2420.csv
# [INFO] processing image vid_4_17580.csv
# [INFO] processing image vid_4_18880.csv
# [INFO] processing image vid_4_16660.csv
# [INFO] processing image vid_4_4520.csv
# [INFO] processing image vid_4_12360.csv
# [INFO] processing image vid_4_21580.csv
# [INFO] processing image vid_4_9560.csv
# [INFO] processing image vid_4_17620.csv
# [INFO] processing image vid_4_1060.csv
# [INFO] processing image vid_4_12200.csv
# [INFO] processing image vid_4_16700.csv
# [INFO] processing image vid_4_6280.csv
# [INFO] processing image vid_4_23020.csv
# [INFO] processing image vid_4_28820.csv
# [INFO] processing image vid_4_9600.csv
# [INFO] processing image vid_4_17420.csv
# [INFO] processing image vid_4_26400.csv
# [INFO] processing image vid_4_12000.csv
# [INFO] processing image vid_4_16500.csv
# [INFO] processing image vid_4_29900.csv
# [INFO] processing image vid_4_8720.csv
# [INFO] processing image vid_4_26560.csv
# [INFO] processing image vid_4_1880.csv
# [INFO] processing image vid_4_12160.csv
# [INFO] processing image vid_4_8640.csv
# [INFO] processing image vid_4_18840.csv
# [INFO] processing image vid_4_9760.csv
# [INFO] processing image vid_4_17540.csv
# [INFO] processing image vid_4_6320.csv
# [INFO] processing image vid_4_600.csv
# [INFO] processing image vid_4_13900.csv
# [INFO] processing image vid_4_11440.csv
# [INFO] processing image vid_4_21540.csv
# [INFO] processing image vid_4_15020.csv
# [INFO] processing image vid_4_21420.csv
# [INFO] processing image vid_4_6240.csv
# [INFO] processing image vid_4_13860.csv
# [INFO] processing image vid_4_13680.csv
# [INFO] processing image vid_4_29520.csv
# [INFO] processing image vid_4_980.csv
# [INFO] processing image vid_4_14460.csv
# [INFO] processing image vid_4_10000.csv
# [INFO] processing image vid_4_14500.csv
# [INFO] processing image vid_4_3260.csv
# [INFO] processing image vid_4_16100.csv
# [INFO] processing image vid_4_8320.csv
# [INFO] processing image vid_4_9980.csv
# [INFO] processing image vid_4_6480.csv
# [INFO] processing image vid_4_2180.csv
# [INFO] processing image vid_4_9200.csv
# [INFO] processing image vid_4_19780.csv
# [INFO] processing image vid_4_17140.csv
# [INFO] processing image vid_4_11280.csv
# [INFO] processing image vid_4_16060.csv
# [INFO] processing image vid_4_8240.csv
# [INFO] processing image vid_4_11900.csv
# [INFO] processing image vid_4_940.csv
# [INFO] processing image vid_4_13640.csv
# [INFO] processing image vid_4_17340.csv
# [INFO] processing image vid_4_21180.csv
# [INFO] processing image vid_4_26360.csv
# [INFO] processing image vid_4_22660.csv
# [INFO] processing image vid_4_3840.csv
# [INFO] processing image vid_4_2380.csv
# [INFO] processing image vid_4_22700.csv
# [INFO] processing image vid_4_16300.csv
# [INFO] processing image vid_4_13720.csv
# [INFO] processing image vid_4_29480.csv
# [INFO] processing image vid_4_9000.csv
# [INFO] processing image vid_4_2140.csv
# [INFO] processing image vid_4_6440.csv
# [INFO] processing image vid_4_19740.csv
# [INFO] processing image vid_4_10980.csv
# [INFO] processing image vid_4_21220.csv
# [INFO] processing image vid_4_11240.csv
# [INFO] processing image vid_4_17180.csv
# [INFO] processing image vid_4_6520.csv
# [INFO] processing image vid_4_2020.csv
# [INFO] processing image vid_4_24760.csv
# [INFO] processing image vid_4_8280.csv
# [INFO] processing image vid_4_9820.csv
# [INFO] processing image vid_4_12220.csv
# [INFO] processing image vid_4_16720.csv
# [INFO] processing image vid_4_13880.csv
# [INFO] processing image vid_4_9420.csv
# [INFO] processing image vid_4_17600.csv
# [INFO] processing image vid_4_1040.csv
# [INFO] processing image vid_4_9540.csv
# [INFO] processing image vid_4_22240.csv
# [INFO] processing image vid_4_12340.csv
# [INFO] processing image vid_4_3520.csv
# [INFO] processing image vid_4_9780.csv
# [INFO] processing image vid_4_18320.csv
# [INFO] processing image vid_4_26580.csv
# [INFO] processing image vid_4_2400.csv
# [INFO] processing image vid_4_29880.csv
# [INFO] processing image vid_4_28220.csv
# [INFO] processing image vid_4_12180.csv
# [INFO] processing image vid_4_1860.csv
# [INFO] processing image vid_4_1900.csv
# [INFO] processing image vid_4_3440.csv
# [INFO] processing image vid_4_21600.csv
# [INFO] processing image vid_4_13840.csv
# [INFO] processing image vid_4_740.csv
# [INFO] processing image vid_4_6260.csv
# [INFO] processing image vid_4_21400.csv
# [INFO] processing image vid_4_15000.csv
# [INFO] processing image vid_4_9580.csv
# [INFO] processing image vid_4_21560.csv
# [INFO] processing image vid_4_12380.csv
# [INFO] processing image vid_4_16680.csv
# [INFO] processing image vid_4_13920.csv
# [INFO] processing image vid_4_6300.csv
# [INFO] processing image vid_4_620.csv
# [INFO] processing image vid_4_17560.csv
# [INFO] processing image vid_4_9740.csv
# [INFO] processing image vid_4_18860.csv
# [INFO] processing image vid_4_8660.csv
# [INFO] processing image vid_4_12140.csv
# [INFO] processing image vid_4_26540.csv
# [INFO] processing image vid_4_8700.csv
# [INFO] processing image vid_4_29920.csv
# [INFO] processing image vid_4_26420.csv
# [INFO] processing image vid_4_17400.csv
# [INFO] processing image vid_4_9620.csv
# [INFO] processing image vid_4_23000.csv
# [INFO] processing image vid_4_11920.csv
# [INFO] processing image vid_4_8260.csv
# [INFO] processing image vid_4_16040.csv
# [INFO] processing image vid_4_17160.csv
# [INFO] processing image vid_4_9340.csv
# [INFO] processing image vid_4_10960.csv
# [INFO] processing image vid_4_30440.csv
# [INFO] processing image vid_4_9220.csv
# [INFO] processing image vid_4_8300.csv
# [INFO] processing image vid_4_16120.csv
# [INFO] processing image vid_4_3240.csv
# [INFO] processing image vid_4_29460.csv
# [INFO] processing image vid_4_10020.csv
# [INFO] processing image vid_4_26380.csv
# [INFO] processing image vid_4_14440.csv
# [INFO] processing image vid_4_2200.csv
# [INFO] processing image vid_4_10140.csv
# [INFO] processing image vid_4_16280.csv
# [INFO] processing image vid_4_29500.csv
# [INFO] processing image vid_4_21160.csv
# [INFO] processing image vid_4_9800.csv
# [INFO] processing image vid_4_6500.csv
# [INFO] processing image vid_4_2000.csv
# [INFO] processing image vid_4_3120.csv
# [INFO] processing image vid_4_11260.csv
# [INFO] processing image vid_4_21200.csv
# [INFO] processing image vid_4_19760.csv
# [INFO] processing image vid_4_9960.csv
# [INFO] processing image vid_4_2160.csv
# [INFO] processing image vid_4_6460.csv
# [INFO] processing image vid_4_11880.csv
# [INFO] processing image vid_4_9020.csv
# [INFO] processing image vid_4_13700.csv
# [INFO] processing image vid_4_16320.csv
# [INFO] processing image vid_4_22720.csv
# [INFO] processing image vid_4_14480.csv
# [INFO] processing image vid_4_26340.csv
# [INFO] processing image vid_4_22640.csv
# [INFO] processing image vid_4_13660.csv
# [INFO] processing image vid_4_17360.csv
# [INFO] processing image vid_4_960.csv
# [INFO] processing image vid_4_13820.csv
# [INFO] processing image vid_4_12280.csv
# [INFO] processing image vid_4_720.csv
# [INFO] processing image vid_4_14140.csv
# [INFO] processing image vid_4_6200.csv
# [INFO] processing image vid_4_21500.csv
# [INFO] processing image vid_4_19060.csv
# [INFO] processing image vid_4_11400.csv
# [INFO] processing image vid_4_6360.csv
# [INFO] processing image vid_4_10520.csv
# [INFO] processing image vid_4_9720.csv
# [INFO] processing image vid_4_8600.csv
# [INFO] processing image vid_4_16420.csv
# [INFO] processing image vid_4_12120.csv
# [INFO] processing image vid_4_19920.csv
# [INFO] processing image vid_4_26520.csv
# [INFO] processing image vid_4_29940.csv
# [INFO] processing image vid_4_12040.csv
# [INFO] processing image vid_4_14380.csv
# [INFO] processing image vid_4_26440.csv
# [INFO] processing image vid_4_28860.csv
# [INFO] processing image vid_4_9640.csv
# [INFO] processing image vid_4_30020.csv
# [INFO] processing image vid_4_10480.csv
# [INFO] processing image vid_4_12240.csv
# [INFO] processing image vid_4_8560.csv
# [INFO] processing image vid_4_9440.csv
# [INFO] processing image vid_4_17660.csv
# [INFO] processing image vid_4_1020.csv
# [INFO] processing image vid_4_9520.csv
# [INFO] processing image vid_4_22220.csv
# [INFO] processing image vid_4_680.csv
# [INFO] processing image vid_4_18180.csv
# [INFO] processing image vid_4_4560.csv
# [INFO] processing image vid_4_12320.csv
# [INFO] processing image vid_4_3540.csv
# [INFO] processing image vid_4_18340.csv
# [INFO] processing image vid_4_6160.csv
# [INFO] processing image vid_4_28240.csv
# [INFO] processing image vid_4_1800.csv
# [INFO] processing image vid_4_19880.csv
# [INFO] processing image vid_4_26480.csv
# [INFO] processing image vid_4_14340.csv
# [INFO] processing image vid_4_29980.csv
# [INFO] processing image vid_4_1960.csv
# [INFO] processing image vid_4_12080.csv
# [INFO] processing image vid_4_21660.csv
# [INFO] processing image vid_4_9860.csv
# [INFO] processing image vid_4_11980.csv
# [INFO] processing image vid_4_2060.csv
# [INFO] processing image vid_4_21300.csv
# [INFO] processing image vid_4_1780.csv
# [INFO] processing image vid_4_3140.csv
# [INFO] processing image vid_4_21260.csv
# [INFO] processing image vid_4_9280.csv
# [INFO] processing image vid_4_9900.csv
# [INFO] processing image vid_4_16180.csv
# [INFO] processing image vid_4_12480.csv
# [INFO] processing image vid_4_22580.csv
# [INFO] processing image vid_4_2100.csv
# [INFO] processing image vid_4_6400.csv
# [INFO] processing image vid_4_9040.csv
# [INFO] processing image vid_4_17260.csv
# [INFO] processing image vid_4_13760.csv
# [INFO] processing image vid_4_860.csv
# [INFO] processing image vid_4_22740.csv
# [INFO] processing image vid_4_26320.csv
# [INFO] processing image vid_4_3800.csv
# [INFO] processing image vid_4_900.csv
# [INFO] processing image vid_4_3380.csv
# [INFO] processing image vid_4_11940.csv
# [INFO] processing image vid_4_16020.csv
# [INFO] processing image vid_4_3180.csv
# [INFO] processing image vid_4_17100.csv
# [INFO] processing image vid_4_9320.csv
# [INFO] processing image vid_4_8980.csv
# [INFO] processing image vid_4_17060.csv
# [INFO] processing image vid_4_9240.csv
# [INFO] processing image vid_4_22540.csv
# [INFO] processing image vid_4_16140.csv
# [INFO] processing image vid_4_3220.csv
# [INFO] processing image vid_4_9080.csv
# [INFO] processing image vid_4_10040.csv
# [INFO] processing image vid_4_10120.csv
# [INFO] processing image vid_4_28440.csv
# [INFO] processing image vid_4_3340.csv
# [INFO] processing image vid_4_11000.csv
# [INFO] processing image vid_4_29560.csv
